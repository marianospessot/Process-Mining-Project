# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# The objective of this project is learn more about Jupyter

# %% [markdown]
# Los lenguajes mas populares en la ciencia de datos son:
# 1. Python
# 2. SQL
# 3. R
# 4. Julia
# 5. Scala

# %% [markdown]
# Las bibliotecas para ciencia de datos son:
# * **Pandas:** Para manipulación de datos
# * **NumPy:** Para computación numérica y operaciones con arreglos.
# * **Matplotlib:** Para visualización de datos estática.
# * **Seaborn:** Para visualización de datos estadística.
# * **Scikit-learn:** Para algoritmos de aprendizaje automático.
# * **TensorFlow/PyTorch:** Para aprendizaje profundo.

# %% [markdown]
# | Categoría         | Herramienta           | Propósito Principal                                     |
# | :---------------- | :-------------------- | :------------------------------------------------------ |
# | Entorno de Trabajo | Jupyter Notebook/Lab | Creación y ejecución interactiva de código y documentos |
# | Lenguajes         | Python                | Lenguaje versátil para análisis y ML                    |
# | Lenguajes         | R                     | Lenguaje estadístico, ideal para visualizaciones        |
# | Bases de Datos    | SQL                   | Consulta y gestión de bases de datos relacionales       |
# | Cloud Computing   | AWS/Azure/GCP         | Infraestructura escalable para proyectos de gran escala |
# | Visualización     | Tableau               | Creación de dashboards interactivos y reportes          |

# %% [markdown]
# Las operaciones aritméticas son las combinaciones que se hacen con los números, siendo las más comunes la suma, resta, multiplicación y división

# %%
# Multiplicación
multiplicacion = 5 * 10
print("El resultado de la multiplicación es:", multiplicacion)

# Suma
suma = 15 + 25
print("El resultado de la suma es:", suma)
# Out:
# El resultado de la multiplicación es: 50
# El resultado de la suma es: 40

# %%
# Cantidad de minutos
minutos = 240

# Convertimos minutos a horas dividiendo por 60
horas = minutos / 60

# Resultado
print(f"{minutos} minutos equivalen a {horas} horas.")
# Out:
# 240 minutos equivalen a 4.0 horas.

# %% [markdown]
# Los objetivos de este proyecto incluyen:
#
# 1.  Demostrar el uso de celdas de Markdown y código.
# 2.  Realizar operaciones aritméticas básicas.
# 3.  Compartir el cuaderno de forma pública a través de GitHub.

# %% [markdown]
# ### Autor:
# Mariano Spessot
